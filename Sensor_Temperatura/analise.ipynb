# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Replace with your file path
file_5k = "5k.txt"
file_10k = "10k.txt"

# Read the txt file (auto-detects delimiter: spaces, tabs, commas)
df_5k = pd.read_csv(file_5k, sep=None, engine="python")
df_10k = pd.read_csv(file_10k, sep=None, engine="python")

# Display the column names and the first few rows of the DataFrame
print("Column Names:", df_5k.columns)
df_5k.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 file_10k = "10k.txt"
#       5 # Read the txt file (auto-detects delimiter: spaces, tabs, commas)
# ----> 6 df_5k = pd.read_csv(file_5k, sep=None, engine="python")
#       7 df_10k = pd.read_csv(file_10k, sep=None, engine="python")
#       9 # Display the column names and the first few rows of the DataFrame
#
# ...

# %%
# Expecting 3 columns
temperature = df.iloc[1:, 0]
vbe = df.iloc[1:, 1]
ic = df.iloc[1:, 2]

plt.figure(figsize=(10, 7))
plt.plot(temperature, vbe, label="VBE")
#plt.plot(temperature, ic, label="IC")

# Adjust the x-axis ticks
plt.xticks(range(-100, 161, 10))

plt.xlabel("Temperature (°C)")
plt.ylabel("VBE (V)")
plt.title("VBE vs Temperature")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Equation for VBE as a function of temperature (example: linear approximation)
coef = np.polyfit(temperature.astype(float), vbe.astype(float), 1)
a = coef[0]
b = coef[1]
print(f"VBE(T) = {a:.4f} * T + {b:.4f}")
# Out:
# VBE(T) = -0.0019 * T + 0.6667

# %%
# Function to calc ulate VBE for a given temperature
def calculate_vbe(temp):
    return a * temp + b

calculate_vbe(-10)  # Example: Calculate VBE at 25°C
# Out:
# np.float64(0.6858574781656663)
